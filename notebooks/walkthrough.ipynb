# %% [markdown]
# # sat-qkd-security-curves walkthrough\n\nCanonical run (from repo root):\n```bash\npython -m sat_qkd_lab.run sweep --loss-min 20 --loss-max 60 --steps 21 --flip-prob 0.005 --pulses 200000 --outdir .\n```\n\nOutputs land in `figures/` and `reports/`.\n
